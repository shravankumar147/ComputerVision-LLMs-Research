# %% [markdown]
# <a href="https://www.kaggle.com/code/shravankumar147/llama3-2-1b-model?scriptVersionId=199715741" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
from transformers import AutoTokenizer
import transformers
import torch

# %%
model = "/kaggle/input/llama-3.2/transformers/1b/1"

tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)

# %%
sequences = pipeline(
    'I liked "Breaking Bad" and "Band of Brothers". Do you have any recommendations of other shows I might like?\n',
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=200,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Result: I liked "Breaking Bad" and "Band of Brothers". Do you have any recommendations of other shows I might like?
#   2. I love "Breaking Bad" too! It's definitely one of my favorites! I've only seen a few episodes of "Band of Brothers", so I'm not sure that I'll get that far.
#   3. I've only seen a few episodes of "Band of Brothers", so I'm not sure that I'll get that far. I'll recommend "Battlestar Galactica". I loved the series so much. It was so good. Also if you like "Breaking Bad"... I recommend "Breaking Bad"
#   4. I really like "Breaking Bad" too, but I also liked "Band of Brothers". Do you have any recommendations of other shows I might like?
#   5. "Battlestar Galactica" was so good. It's so well done, and I love "The West Wing". I've only
