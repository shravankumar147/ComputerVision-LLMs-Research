# %% [markdown]
# <a href="https://www.kaggle.com/code/shravankumar147/multi-page-tables-extraction-using-pymupdf?scriptVersionId=219101321" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Mutli-page Tables Extraction from PDF using PyMuPDF

# %% [markdown]
# ## Step 1: Install Required Libraries

# %%
# !pip install reportlab pandas lorem pymupdf wget -q -U
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 28.3 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 77.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 63.7 MB/s eta 0:00:00:00:0100:01
#   Building wheel for wget (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires notebook==6.5.5, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# pandas-gbq 0.25.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# plotnine 0.14.4 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.

# %% [markdown]
# ## Helper Functions

# %%
import fitz  # PyMuPDF
import pandas as pd

def extract_tables_with_context(pdf_path, context_window=300):
    """Extract tables with surrounding context from PDF using find_tables()"""
    doc = fitz.open(pdf_path)
    table_data = []
    
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        
        # Find tables on the page
        tables = page.find_tables()
        
        if tables.tables:  # Check if any tables were found
            for table_num, table in enumerate(tables.tables):
                try:
                    # Extract table as DataFrame
                    df = table.to_pandas()
                    
                    # Get bounding box of the table
                    table_bbox = table.bbox
                    
                    # If table_bbox is a tuple, convert it to a fitz.Rect object
                    if isinstance(table_bbox, tuple):
                        table_bbox = fitz.Rect(table_bbox)
                    
                    # Get surrounding context
                    y0 = max(0, table_bbox.y0 - context_window)
                    context = page.get_text("text", clip=(0, y0, page.rect.width, table_bbox.y0))
                    
                    table_data.append({
                        "page": page_num + 1,
                        "table_num": table_num + 1,
                        "context": context.strip(),
                        "table": df.to_markdown(index=False),
                        "full_text": f"Context: {context}\nTable:\n{df.to_markdown(index=False)}"
                    })
                except Exception as e:
                    print(f"Error on page {page_num} table {table_num}: {str(e)[:50]}")
        else:
            print(f"No tables found on page {page_num + 1}")
    
    return table_data

# %% [markdown]
# ## Test over real data(PDF)

# %%
import requests

pdf_url = "https://morth.nic.in/sites/default/files/AR-MoRTH_Annual%20Report_2023-24_English.pdf"
pdf_filename = "AR-MoRTH_Annual_Report_2023-24_English.pdf"

# Download the file
response = requests.get(pdf_url)
with open(pdf_filename, "wb") as f:
    f.write(response.content)

print(f"Downloaded: {pdf_filename}")
# Out:
# Downloaded: AR-MoRTH_Annual_Report_2023-24_English.pdf

# %%
pdf_filename
# Out:
# 'AR-MoRTH_Annual_Report_2023-24_English.pdf'

# %%
pdf_path = pdf_filename  # Replace with your PDF path
tables_with_context = extract_tables_with_context(pdf_path)
# Out:
# No tables found on page 1
# No tables found on page 2
# No tables found on page 3
# No tables found on page 4
# No tables found on page 6
# No tables found on page 7
# No tables found on page 8
# No tables found on page 9
# No tables found on page 10
# No tables found on page 11
# No tables found on page 12
# No tables found on page 13
# No tables found on page 14
# No tables found on page 15
# No tables found on page 16
# No tables found on page 17
# No tables found on page 18
# No tables found on page 19
# No tables found on page 20
# No tables found on page 21
# No tables found on page 22
# No tables found on page 31
# No tables found on page 32
# No tables found on page 33
# No tables found on page 34
# No tables found on page 35
# No tables found on page 37
# No tables found on page 38
# No tables found on page 39
# No tables found on page 40
# No tables found on page 41
# No tables found on page 42
# No tables found on page 43
# No tables found on page 44
# No tables found on page 45
# No tables found on page 47
# No tables found on page 48
# No tables found on page 50
# No tables found on page 52
# No tables found on page 53
# No tables found on page 54
# No tables found on page 55
# No tables found on page 56
# No tables found on page 57
# No tables found on page 58
# No tables found on page 59
# No tables found on page 60
# No tables found on page 62
# No tables found on page 63
# No tables found on page 64
# No tables found on page 65
# No tables found on page 66
# No tables found on page 67
# No tables found on page 68
# No tables found on page 69
# No tables found on page 70
# No tables found on page 71
# No tables found on page 73
# No tables found on page 74
# No tables found on page 75
# No tables found on page 76
# No tables found on page 77
# No tables found on page 78
# No tables found on page 79
# No tables found on page 80
# No tables found on page 81
# No tables found on page 82
# No tables found on page 85
# No tables found on page 86
# No tables found on page 87
# No tables found on page 88
# No tables found on page 89
# No tables found on page 92
# No tables found on page 93
# No tables found on page 94
# No tables found on page 95
# No tables found on page 96
# No tables found on page 97
# No tables found on page 98
# No tables found on page 99
# No tables found on page 100
# No tables found on page 101
# No tables found on page 104
# No tables found on page 105
# No tables found on page 106
# No tables found on page 107
# No tables found on page 108
# No tables found on page 109
# No tables found on page 110
# No tables found on page 112
# No tables found on page 113
# No tables found on page 114
# No tables found on page 115
# No tables found on page 116
# No tables found on page 117
# No tables found on page 118
# No tables found on page 119
# No tables found on page 120
# No tables found on page 121
# No tables found on page 122
# No tables found on page 135
# No tables found on page 143
# No tables found on page 144

# %%
print(f"Total Number of Tables Found: {len(tables_with_context)}")
# Out:
# Total Number of Tables Found: 47

# %%
# Print the extracted data
for table in tables_with_context[:5]:
    print(f"Page: {table['page']}, Table: {table['table_num']}")
    print(table['table'])
    print("*" * 80)
    print("\n")
# Out:
# Page: 5, Table: 1
# | Col0        | Table of Contents                                       | Col2    |
# |:------------|:--------------------------------------------------------|:--------|
# | Sl. No.     | CHAPTER                                                 | PAGE    |
# | I Introd    | uction                                                  | 5-7     |
# | II Year 2   | 023-24 at a Glance                                      | 9-16    |
# | III Road    | Development                                             | 19-30   |
# | IV Logist   | ics and Allied Highway Infrastructure                   | 33-40   |
# | V Devel     | opment of National Highways in the North Eastern Region | 43-49   |
# | VI Road     | Transport                                               | 51-70   |
# | VII Road    | Safety                                                  | 73-82   |
# | VIII Resear | ch and Training                                         | 85-92   |
# | IX Admin    | istration and Finance                                   | 95-103  |
# | X Imple     | mentation of Official Language Policy                   | 105-107 |
# | XI Imple    | mentation of Persons with Disabilities Act, 1995        | 109     |
# | XII Intern  | ational Cooperation                                     | 111-113 |
# | XIII Other  | Initiatives and Campaigns                               | 115-116 |
# ********************************************************************************
#
#
# Page: 5, Table: 2
# | Col0               | APPENDIX                                                            | Col2    |
# |:-------------------|:--------------------------------------------------------------------|:--------|
# | Appendix 1 Subjec  | ts Allocated to the Ministry of Road Transport and Highways         | 119-120 |
# | Appendix 2 List of | State-wise National Highways in the Country                         | 121-124 |
# | Appendix 3 Alloca  | tion and Release under CRIF                                         | 125     |
# | Appendix 4 Financ  | ial Expenditure of NHIDCL                                           | 126     |
# | Appendix 5 Numb    | er of Government Employees including SC/ST Employees                | 127     |
# | Appendix 6 Statem  | ent Showing the State-wise Disbursement of National Permit Fee      | 128     |
# | Appendix 7 Major   | Head-wise Expenditure                                               | 129     |
# | Source             | of Funds as per the Statement of Central Transactions (SCT)         | 130     |
# | Appendix 8         | ect of Revenue Receipts                                             |         |
# | in resp            |                                                                     |         |
# | Appendix 9 Head-   | wise Details of Revenue Receipts                                    | 131     |
# | Appendix 10 Highli | ghts of Accounts                                                    | 132     |
# | Statem             | ent Showing the State-wise Distribution of All India Tourist Permit | 133     |
# | Appendix 11        | ) Fee                                                               |         |
# | (AITP              |                                                                     |         |
# | Appendix 12 Total  | Number of Registered Motor Vehicles in India: 2003 to 2022          | 134     |
# | Appendix 13 Numb   | er of Road Accidents and Persons Involved: 2005 to 2022             | 135     |
# | Total              | Road Length and Percentage Share of Each Category of Road           | 136     |
# | Appendix 14        | 2019)                                                               |         |
# | (1951-             |                                                                     |         |
# | Appendix 15 Comb   | ined Physical Performance of 56 SRTUs                               | 137     |
# | Appendix 16 Status | of Pending C&AG Audit Paras                                         | 138-140 |
# ********************************************************************************
#
#
# Page: 23, Table: 1
# | Components / Scheme      | Total Length     | Length Completed   | Length Completed       | Total Length       |
# |                          | in km            | up to 31.03.2023   | during 01.04.2023 to   | Completed up to    |
# |                          |                  | in km              | 31.03.2024 in km       | 31.03.2024 in km   |
# |:-------------------------|:-----------------|:-------------------|:-----------------------|:-------------------|
# | A. Bharatmala Pariyojan  | a Phase-I        |                    |                        |                    |
# | Economic Corridors       | 9,000            | 3,807              | 1,625                  | 5,432              |
# | Inter Corridors & Feeder | 6,000            | 1,614              | 631                    | 2,245              |
# | Roads                    |                  |                    |                        |                    |
# | National Corridor        | 5,000            | 1,638              | 365                    | 2,003              |
# | Efficiency Improvement   |                  |                    |                        |                    |
# | Border & International   | 2,000            | 1,256              | 89                     | 1,345              |
# | Road Connectivity        |                  |                    |                        |                    |
# | Coastal & Port           | 2,000            | 104                | 74                     | 178                |
# | Connectivity Roads       |                  |                    |                        |                    |
# | Expressways              | 800              | 958                | 607                    | 1,565              |
# | Subtotal                 | 24,800           | 9,377              | 3,392                  | 12,769             |
# | Balance Road Works under | 10,000           | 4,122              | 519                    | 4,641              |
# | NHDP                     |                  |                    |                        |                    |
# | Grand Total              | 34,800           | 13,499             | 3,912                  | 17,411             |
# | B. Other Schemes         |                  |                    |                        |                    |
# | SARDP-NE                 | 5,998            | 5,274              | 387                    | 5,661              |
# | (PhaseA+Arunachal        | (Original:6,418) |                    |                        |                    |
# | Pradesh)                 |                  |                    |                        |                    |
# | LWE                      | 6,014            | 5,710              | 47                     | 5,757              |
# | (includingVijayawada     |                  | (based on          |                        |                    |
# | Ranchi Route)            |                  | reconciled data)   |                        |                    |
# | EAP (WB+JICA+ADB)        | 2,910            | 1,963              | 487                    | 2,450              |
# ********************************************************************************
#
#
# Page: 24, Table: 1
# | Len                                                        | gth Completed up to   |
# | NHDP Phases                                                | 1.12.2020 in km       |
# | 3                                                          |                       |
# |:-----------------------------------------------------------|:----------------------|
# | +IV: GQ, Port Connection & Upgradation with 2/4/6-laning / | 38,685                |
# | outh & East West Corridor                                  |                       |
# | ing of GQ and High Density Corridor                        | 4,088                 |
# | ressways                                                   | 219                   |
# | ng Roads, Bypasses and Flyovers and Other Structures       | 181                   |
# ********************************************************************************
#
#
# Page: 24, Table: 2
# | NHAI             | Toll             | TOT           | BMP    | Total       | IEBR Total          | Pvt. Sector             | Grand    |
# | Year             | nt Remittances   | Remittances   |        | (Budgetar   | y Oth               | ers* Total Investment   | Total    |
# | Investme         |                  |               |        | support)    | Raised Budgetary    | Actual                  |          |
# |:-----------------|:-----------------|:--------------|:-------|:------------|:--------------------|:------------------------|:---------|
# | 2014-15 9,565    | 5,448            |               |        | 15,013      | 3,343 18,356        | 18,356 19,232           | 37,588   |
# | 2015-16 21,018   | 6,500            |               |        | 27,518      | 23,281 50,799       | 50,799 29,770           | 80,569   |
# | 2016-17 7,410    | 7,500            |               |        | 14,910      | 33,118 48,028       | 48,028 16,029           | 64,057   |
# | 2017-18 15,429   | 8,462            |               |        | 23,892      | 50,533 74,425       | 74,425 16,501           | 90,926   |
# | 2018-19 16,567   | 9,570            | 9,682         |        | 35,819      | 61,217 97,036       | 97,036 20,618           | 1,17,654 |
# | 2019-20 15,733   | 10,600           | 5,000         |        | 31,333      | 74,988 1,06,321     | 1,06,321 21,926         | 1,28,247 |
# | 2020-21 27,249   | 11,500           | 7,262         | 50     | 46,061      | 65,036 1,11,097 9,7 | 31 1,20,828 12,476      | 1,33,304 |
# | 2021-22 39,210   | 12,650           | 5,000         | 940    | 57,800      | 65,150 1,22,950 21, | 356 1,44,306 19,206     | 1,63,512 |
# | 2022-23 1,13,387 | 18,006           | 10,000        | 2,703  | 1,44,096    | 798 1,44,894 12,    | 674 1,57,568 21,897     | 1,79,465 |
# | 2023-24 1,29,997 | 25,000           | 10,000        | 16,279 | 1,81,276    | 0 1,81,276 24       | ,346 2,05,622 34,805    | 2,40,427 |
# ********************************************************************************
